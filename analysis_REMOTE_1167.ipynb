# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from scipy.stats import linregress

# File to Load (Remember to Change These)
unemployed = Path("Resources/Unemployment_Canada_1976_present.csv")

# %% [markdown]
# # Unemployment

# %%
unemployed_df = pd.read_csv(unemployed)
unemployed_df.head()
# Out:
#   REF_DATE      GEO         Sex          Age group  Employment  \
# 0  1976-01  Alberta  Both sexes     15 to 24 years    231800.0
# 1  1976-01  Alberta  Both sexes     15 to 64 years    802400.0
# 2  1976-01  Alberta  Both sexes  15 years and over    819500.0
# 3  1976-01  Alberta  Both sexes     25 to 54 years    491400.0
# 4  1976-01  Alberta  Both sexes  25 years and over    587700.0
#
#    Full-time employment  Labour force  Part-time employment   Population  \
# 0              174900.0      252300.0                56900.0    362300.0
# 1              682100.0      837500.0               120300.0   1154800.0
# 2              693700.0      856500.0               125800.0   1276700.0
# 3              439800.0      505800.0                51600.0    661700.0
# 4              518800.0      604200.0                68900.0    914400.0
#
#    Unemployment  Employment rate  Participation rate  Unemployment rate
# 0       20500.0             64.0                69.6                8.1
# 1       35000.0             69.5                72.5                4.2
# 2       37000.0             64.2                67.1                4.3
# 3       14400.0             74.3                76.4                2.8
# 4       16500.0             64.3                66.1                2.7

# %%
#Filtering sex, part time labour and full time labour out of the data frame.
filt_unemployed_df = unemployed_df.filter(items= ["REF_DATE", "GEO", "Age group", "Population", "Labour force", "Employment","Unemployment",
                           "Participation rate", "Employment rate", "Unemployment rate"])

#Dropping NA values
filt_unemployed_df.dropna(inplace=True)

#Creating a copy of the data frame for manipulation later
copy_filt_unemploy_df = filt_unemployed_df.copy()

#Preview of the data
filt_unemployed_df.head()
# Out:
#   REF_DATE      GEO          Age group  Population  Labour force  Employment  \
# 0  1976-01  Alberta     15 to 24 years    362300.0      252300.0    231800.0
# 1  1976-01  Alberta     15 to 64 years   1154800.0      837500.0    802400.0
# 2  1976-01  Alberta  15 years and over   1276700.0      856500.0    819500.0
# 3  1976-01  Alberta     25 to 54 years    661700.0      505800.0    491400.0
# 4  1976-01  Alberta  25 years and over    914400.0      604200.0    587700.0
#
#    Unemployment  Participation rate  Employment rate  Unemployment rate
# 0       20500.0                69.6             64.0                8.1
# 1       35000.0                72.5             69.5                4.2
# 2       37000.0                67.1             64.2                4.3
# 3       14400.0                76.4             74.3                2.8
# 4       16500.0                66.1             64.3                2.7

# %%
filt_unemployed_df["Year"] = ""
filt_unemployed_df["Month"] = ""



filt_unemployed_df.head()
# Out:
#   REF_DATE      GEO          Age group  Population  Labour force  Employment  \
# 0  1976-01  Alberta     15 to 24 years    362300.0      252300.0    231800.0
# 1  1976-01  Alberta     15 to 64 years   1154800.0      837500.0    802400.0
# 2  1976-01  Alberta  15 years and over   1276700.0      856500.0    819500.0
# 3  1976-01  Alberta     25 to 54 years    661700.0      505800.0    491400.0
# 4  1976-01  Alberta  25 years and over    914400.0      604200.0    587700.0
#
#    Unemployment  Participation rate  Employment rate  Unemployment rate Year  \
# 0       20500.0                69.6             64.0                8.1
# 1       35000.0                72.5             69.5                4.2
# 2       37000.0                67.1             64.2                4.3
# 3       14400.0                76.4             74.3                2.8
# 4       16500.0                66.1             64.3                2.7
#
#   Month
# 0
# 1
# 2
# 3
# 4

# %%
for i, row in filt_unemployed_df.iterrows():
    date = row["REF_DATE"].split("-")
    filt_unemployed_df.loc[i,"Year"] = date[0]
    filt_unemployed_df.loc[i,"Month"] = date[1]
   

filt_unemployed_df.head()
# Out:
#   REF_DATE      GEO          Age group  Population  Labour force  Employment  \
# 0  1976-01  Alberta     15 to 24 years    362300.0      252300.0    231800.0
# 1  1976-01  Alberta     15 to 64 years   1154800.0      837500.0    802400.0
# 2  1976-01  Alberta  15 years and over   1276700.0      856500.0    819500.0
# 3  1976-01  Alberta     25 to 54 years    661700.0      505800.0    491400.0
# 4  1976-01  Alberta  25 years and over    914400.0      604200.0    587700.0
#
#    Unemployment  Participation rate  Employment rate  Unemployment rate  Year  \
# 0       20500.0                69.6             64.0                8.1  1976
# 1       35000.0                72.5             69.5                4.2  1976
# 2       37000.0                67.1             64.2                4.3  1976
# 3       14400.0                76.4             74.3                2.8  1976
# 4       16500.0                66.1             64.3                2.7  1976
#
#   Month
# 0    01
# 1    01
# 2    01
# 3    01
# 4    01

# %%
filt_unemployed_df = filt_unemployed_df.filter(items= ["Year","Month", "GEO", "Age group", "Population", "Labour force", "Employment","Unemployment",
                           "Participation rate", "Employment rate", "Unemployment rate"])

filt_unemployed_df.head()
# Out:
#    Year Month      GEO          Age group  Population  Labour force  \
# 0  1976    01  Alberta     15 to 24 years    362300.0      252300.0
# 1  1976    01  Alberta     15 to 64 years   1154800.0      837500.0
# 2  1976    01  Alberta  15 years and over   1276700.0      856500.0
# 3  1976    01  Alberta     25 to 54 years    661700.0      505800.0
# 4  1976    01  Alberta  25 years and over    914400.0      604200.0
#
#    Employment  Unemployment  Participation rate  Employment rate  \
# 0    231800.0       20500.0                69.6             64.0
# 1    802400.0       35000.0                72.5             69.5
# 2    819500.0       37000.0                67.1             64.2
# 3    491400.0       14400.0                76.4             74.3
# 4    587700.0       16500.0                66.1             64.3
#
#    Unemployment rate
# 0                8.1
# 1                4.2
# 2                4.3
# 3                2.8
# 4                2.7

# %%
filt_unemployed_df["GEO"].unique()
# Out:
# array(['Alberta', 'British Columbia', 'Canada', 'Manitoba',
#        'New Brunswick', 'Newfoundland and Labrador', 'Nova Scotia',
#        'Ontario', 'Prince Edward Island', 'Quebec', 'Saskatchewan'],
#       dtype=object)

# %%
provincial_unemploy = filt_unemployed_df.loc[filt_unemployed_df["GEO"] != "Canada"]
provincial_unemploy = filt_unemployed_df.loc[filt_unemployed_df["Age group"] == "15 years and over"]  
provincial_unemploy = provincial_unemploy[provincial_unemploy["Month"]== "01"]
provincial_unemploy
# Out:
#        Year Month                   GEO          Age group  Population  \
# 2      1976    01               Alberta  15 years and over   1276700.0
# 8      1976    01      British Columbia  15 years and over   1852400.0
# 15     1976    01                Canada  15 years and over  16852400.0
# 23     1976    01              Manitoba  15 years and over    732900.0
# 29     1976    01         New Brunswick  15 years and over    476800.0
# ...     ...   ...                   ...                ...         ...
# 38957  2023    01           Nova Scotia  15 years and over    851700.0
# 38963  2023    01               Ontario  15 years and over  12628200.0
# 38969  2023    01  Prince Edward Island  15 years and over    141500.0
# 38975  2023    01                Quebec  15 years and over   7204500.0
# 38981  2023    01          Saskatchewan  15 years and over    912000.0
#
#        Labour force  Employment  Unemployment  Participation rate  \
# 2          856500.0    819500.0       37000.0                67.1
# 8         1125400.0   1029700.0       95800.0                60.8
# 15       10369700.0   9636700.0      733000.0                61.5
# 23         452800.0    427400.0       25300.0                61.8
# 29         258700.0    229600.0       29100.0                54.3
# ...             ...         ...           ...                 ...
# 38957      528100.0    501600.0       26500.0                62.0
# 38963     8276300.0   7849700.0      426600.0                65.5
# 38969       90800.0     83900.0        7000.0                64.2
# 38975     4696900.0   4511600.0      185300.0                65.2
# 38981      615500.0    589000.0       26500.0                67.5
#
#        Employment rate  Unemployment rate
# 2                 64.2                4.3
# 8                 55.6                8.5
# 15                57.2                7.1
# 23                58.3                5.6
# 29                48.2               11.2
# ...                ...                ...
# 38957             58.9                5.0
# 38963             62.2                5.2
# 38969             59.3                7.7
# 38975             62.6                3.9
# 38981             64.6                4.3
#
# [528 rows x 11 columns]

# %% [markdown]
# # Unemployment vs Expenditure

# %%
household_spending = Path("Resources/Household spending.csv")
household_spending_df = pd.read_csv(household_spending)
household_spending_df.head()
# Out:
#    REF_DATE     GEO           DGUID                          Statistic  \
# 0      2010  Canada  2016A000011124  Average expenditure per household
# 1      2010  Canada  2016A000011124  Average expenditure per household
# 2      2010  Canada  2016A000011124  Average expenditure per household
# 3      2010  Canada  2016A000011124  Average expenditure per household
# 4      2010  Canada  2016A000011124  Average expenditure per household
#
#   Household expenditures, summary-level categories      UOM  UOM_ID  \
# 0                                Total expenditure  Dollars      81
# 1                        Total current consumption  Dollars      81
# 2                                Food expenditures  Dollars      81
# 3                       Food purchased from stores  Dollars      81
# 4                                  Bakery products  Dollars      81
#
#   SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE    VALUE STATUS  SYMBOL  \
# 0         units          0  v54325508      1.1.1  72075.0    NaN     NaN
# 1         units          0  v54325509      1.1.2  54013.0    NaN     NaN
# 2         units          0  v54325510      1.1.3   7850.0    NaN     NaN
# 3         units          0  v54325511      1.1.4   5709.0    NaN     NaN
# 4         units          0  v64469102     1.1.43    581.0    NaN     NaN
#
#   TERMINATED  DECIMALS
# 0        NaN         0
# 1        NaN         0
# 2        NaN         0
# 3        NaN         0
# 4        NaN         0

# %%
filt_spending_df = household_spending_df.filter(items= ["REF_DATE", "GEO", "Household expenditures, summary-level categories", "VALUE"])
filt_spending_df = filt_spending_df.rename (columns={"REF_DATE": "Year", "Household expenditures, summary-level categories": "Categories", "VALUE":"Average Spending"})
filt_spending_df
# Out:
#        Year               GEO  \
# 0      2010            Canada
# 1      2010            Canada
# 2      2010            Canada
# 3      2010            Canada
# 4      2010            Canada
# ...     ...               ...
# 40373  2021  British Columbia
# 40374  2021  British Columbia
# 40375  2021  British Columbia
# 40376  2021  British Columbia
# 40377  2021  British Columbia
#
#                                             Categories  Average Spending
# 0                                    Total expenditure           72075.0
# 1                            Total current consumption           54013.0
# 2                                    Food expenditures            7850.0
# 3                           Food purchased from stores            5709.0
# 4                                      Bakery products             581.0
# ...                                                ...               ...
# 40373              Gifts of money and support payments            1052.0
# 40374       Gifts of money to persons living in Canada             594.0
# 40375  Gifts of money to persons living outside Canada             213.0
# 40376                        Alimony and child support               NaN
# 40377                         Charitable contributions             724.0
#
# [40378 rows x 4 columns]

# %%
#Change the data to yearly average

provincial_unemploy_avg_df = provincial_unemploy.filter(items= ["Year", "GEO", "Population", "Labour force", "Employment","Unemployment",
                           "Participation rate", "Employment rate", "Unemployment rate"])
provincial_unemploy_avg_df


#provincial_unemploy_avg_df = provincial_unemploy_avg_df.groupby(["Year","GEO"])
provincial_unemploy_avg_df = provincial_unemploy_avg_df.reset_index()

print(provincial_unemploy_avg_df.columns)
provincial_unemploy_avg_df
# Out:
# Index(['index', 'Year', 'GEO', 'Population', 'Labour force', 'Employment',
#        'Unemployment', 'Participation rate', 'Employment rate',
#        'Unemployment rate'],
#       dtype='object')
#      index  Year                   GEO  Population  Labour force  Employment  \
# 0        2  1976               Alberta   1276700.0      856500.0    819500.0
# 1        8  1976      British Columbia   1852400.0     1125400.0   1029700.0
# 2       15  1976                Canada  16852400.0    10369700.0   9636700.0
# 3       23  1976              Manitoba    732900.0      452800.0    427400.0
# 4       29  1976         New Brunswick    476800.0      258700.0    229600.0
# ..     ...   ...                   ...         ...           ...         ...
# 523  38957  2023           Nova Scotia    851700.0      528100.0    501600.0
# 524  38963  2023               Ontario  12628200.0     8276300.0   7849700.0
# 525  38969  2023  Prince Edward Island    141500.0       90800.0     83900.0
# 526  38975  2023                Quebec   7204500.0     4696900.0   4511600.0
# 527  38981  2023          Saskatchewan    912000.0      615500.0    589000.0
#
#      Unemployment  Participation rate  Employment rate  Unemployment rate
# 0         37000.0                67.1             64.2                4.3
# 1         95800.0                60.8             55.6                8.5
# 2        733000.0                61.5             57.2                7.1
# 3         25300.0                61.8             58.3                5.6
# 4         29100.0                54.3             48.2               11.2
# ..            ...                 ...              ...                ...
# 523       26500.0                62.0             58.9                5.0
# 524      426600.0                65.5             62.2                5.2
# 525        7000.0                64.2             59.3                7.7
# 526      185300.0                65.2             62.6                3.9
# 527       26500.0                67.5             64.6                4.3
#
# [528 rows x 10 columns]

# %%
#Merge 2 dataset
provincial_unemploy_avg_df['Year'] = provincial_unemploy_avg_df['Year'].astype(int)
filt_spending_df['Year'] = filt_spending_df['Year'].astype(int)

Spending_Unemployment = pd.merge(filt_spending_df, provincial_unemploy_avg_df, how="left", on=["Year", "GEO"])
Spending_Unemployment = Spending_Unemployment.drop("index",axis=1)
Spending_Unemployment
# Out:
#        Year               GEO  \
# 0      2010            Canada
# 1      2010            Canada
# 2      2010            Canada
# 3      2010            Canada
# 4      2010            Canada
# ...     ...               ...
# 40373  2021  British Columbia
# 40374  2021  British Columbia
# 40375  2021  British Columbia
# 40376  2021  British Columbia
# 40377  2021  British Columbia
#
#                                             Categories  Average Spending  \
# 0                                    Total expenditure           72075.0
# 1                            Total current consumption           54013.0
# 2                                    Food expenditures            7850.0
# 3                           Food purchased from stores            5709.0
# 4                                      Bakery products             581.0
# ...                                                ...               ...
# 40373              Gifts of money and support payments            1052.0
# 40374       Gifts of money to persons living in Canada             594.0
# 40375  Gifts of money to persons living outside Canada             213.0
# 40376                        Alimony and child support               NaN
# 40377                         Charitable contributions             724.0
#
#        Population  Labour force  Employment  Unemployment  Participation rate  \
# 0      27403500.0    18361700.0  16824300.0     1537400.0                67.0
# 1      27403500.0    18361700.0  16824300.0     1537400.0                67.0
# 2      27403500.0    18361700.0  16824300.0     1537400.0                67.0
# 3      27403500.0    18361700.0  16824300.0     1537400.0                67.0
# 4      27403500.0    18361700.0  16824300.0     1537400.0                67.0
# ...           ...           ...         ...           ...                 ...
# 40373   4320600.0     2849200.0   2631000.0      218200.0                65.9
# 40374   4320600.0     2849200.0   2631000.0      218200.0                65.9
# 40375   4320600.0     2849200.0   2631000.0      218200.0                65.9
# 40376   4320600.0     2849200.0   2631000.0      218200.0                65.9
# 40377   4320600.0     2849200.0   2631000.0      218200.0                65.9
#
#        Employment rate  Unemployment rate
# 0                 61.4                8.4
# 1                 61.4                8.4
# 2                 61.4                8.4
# 3                 61.4                8.4
# 4                 61.4                8.4
# ...                ...                ...
# 40373             60.9                7.7
# 40374             60.9                7.7
# 40375             60.9                7.7
# 40376             60.9                7.7
# 40377             60.9                7.7
#
# [40378 rows x 11 columns]

# %%
#Filter for insurance premium
insurance_df = Spending_Unemployment[Spending_Unemployment["Categories"] == "Personal insurance payments and pension contributions"]
insurance_df.dropna(inplace=True)
insurance_df
# Out:
# C:\Users\Rob\AppData\Local\Temp\ipykernel_10000\3967519840.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insurance_df.dropna(inplace=True)
#        Year                        GEO  \
# 305    2010                     Canada
# 937    2010  Newfoundland and Labrador
# 1253   2010       Prince Edward Island
# 1569   2010                Nova Scotia
# 1885   2010              New Brunswick
# ...     ...                        ...
# 38883  2021                    Ontario
# 39477  2021                   Manitoba
# 39774  2021               Saskatchewan
# 40071  2021                    Alberta
# 40368  2021           British Columbia
#
#                                               Categories  Average Spending  \
# 305    Personal insurance payments and pension contri...            4018.0
# 937    Personal insurance payments and pension contri...            3665.0
# 1253   Personal insurance payments and pension contri...            3674.0
# 1569   Personal insurance payments and pension contri...            3707.0
# 1885   Personal insurance payments and pension contri...            3762.0
# ...                                                  ...               ...
# 38883  Personal insurance payments and pension contri...            5625.0
# 39477  Personal insurance payments and pension contri...            5491.0
# 39774  Personal insurance payments and pension contri...            5357.0
# 40071  Personal insurance payments and pension contri...            6148.0
# 40368  Personal insurance payments and pension contri...            5267.0
#
#        Population  Labour force  Employment  Unemployment  Participation rate  \
# 305    27403500.0    18361700.0  16824300.0     1537400.0                67.0
# 937      435700.0      258300.0    218800.0       39600.0                59.3
# 1253     115400.0       78300.0     70500.0        7900.0                67.9
# 1569     774100.0      493800.0    448100.0       45700.0                63.8
# 1885     615800.0      397100.0    360400.0       36600.0                64.5
# ...           ...           ...         ...           ...                 ...
# 38883  12280500.0     7894500.0   7086100.0      808400.0                64.3
# 39477   1049400.0      686500.0    631400.0       55100.0                65.4
# 39774    888100.0      597800.0    555700.0       42100.0                67.3
# 40071   3527700.0     2452000.0   2199600.0      252400.0                69.5
# 40368   4320600.0     2849200.0   2631000.0      218200.0                65.9
#
#        Employment rate  Unemployment rate
# 305               61.4                8.4
# 937               50.2               15.3
# 1253              61.1               10.1
# 1569              57.9                9.3
# 1885              58.5                9.2
# ...                ...                ...
# 38883             57.7               10.2
# 39477             60.2                8.0
# 39774             62.6                7.0
# 40071             62.4               10.3
# 40368             60.9                7.7
#
# [110 rows x 11 columns]

# %% [markdown]
# Create Charts for Insurance payments

# %%
# filter for Ontario only
insurance_on_df = insurance_df[insurance_df["GEO"]== "Ontario"]

year = insurance_on_df["Year"]
avg_unemployment = insurance_on_df["Unemployment rate"]
avg_employment = insurance_on_df["Employment rate"]
avg_spending = insurance_on_df["Average Spending"]

fig, ax = plt.subplots()
ax.bar(year, avg_spending, color='blue', label="Average Spending")

ax2= ax.twinx()

#ax2.plot(year, avg_employment, color='green', label="Employment Rate")
ax2.plot(year, avg_unemployment, color='red', label="Unemployment Rate")

ax.legend()

ax.plot()
# Out:
# []

# %% [markdown]
# # Unemployment vs Immigration

# %%
immigration = Path("Resources/Immigration_Data.csv")
immigration_df = pd.read_csv(immigration)

immigration_df.head()
# Out:
#     REF_DATE                        GEO        DGUID          Gender  \
# 0  1971/1972  Newfoundland and Labrador  2016A000210  Total - gender
# 1  1972/1973  Newfoundland and Labrador  2016A000210  Total - gender
# 2  1973/1974  Newfoundland and Labrador  2016A000210  Total - gender
# 3  1974/1975  Newfoundland and Labrador  2016A000210  Total - gender
# 4  1975/1976  Newfoundland and Labrador  2016A000210  Total - gender
#
#   Type of migrant Age group      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# 0      Immigrants  All ages  Persons     249         units          0
# 1      Immigrants  All ages  Persons     249         units          0
# 2      Immigrants  All ages  Persons     249         units          0
# 3      Immigrants  All ages  Persons     249         units          0
# 4      Immigrants  All ages  Persons     249         units          0
#
#     VECTOR COORDINATE  VALUE  STATUS  SYMBOL  TERMINATED  DECIMALS
# 0  v437654    2.1.1.1    729     NaN     NaN         NaN         0
# 1  v437654    2.1.1.1    751     NaN     NaN         NaN         0
# 2  v437654    2.1.1.1   1128     NaN     NaN         NaN         0
# 3  v437654    2.1.1.1    995     NaN     NaN         NaN         0
# 4  v437654    2.1.1.1   1013     NaN     NaN         NaN         0

# %%
#Filtering sex, part time labour and full time labour out of the data frame.
filt_immigration_df = immigration_df.filter(items= ["REF_DATE", "GEO", "Age group", "VALUE"])
filt_immigration_df.rename(columns={'VALUE': 'Total Immigrants'}, inplace=True)
#Dropping NA values
filt_immigration_df.dropna(inplace=True)


#Preview of the data
filt_immigration_df.head()
# Out:
#     REF_DATE                        GEO Age group  Total Immigrants
# 0  1971/1972  Newfoundland and Labrador  All ages               729
# 1  1972/1973  Newfoundland and Labrador  All ages               751
# 2  1973/1974  Newfoundland and Labrador  All ages              1128
# 3  1974/1975  Newfoundland and Labrador  All ages               995
# 4  1975/1976  Newfoundland and Labrador  All ages              1013

# %%
#Filtering by starting year
filt_immigration_df["Year"] = ""
filt_immigration_df.head()

for i, row in filt_immigration_df.iterrows():
    date = row["REF_DATE"].split("/")
    filt_immigration_df.loc[i,"Year"] = date[0]
    
#Arranging columns   
filt_immigration_df = filt_immigration_df.filter(items= ["Year", "GEO", "Age group", "Total Immigrants"])

filt_immigration_df.head()
# Out:
#    Year                        GEO Age group  Total Immigrants
# 0  1971  Newfoundland and Labrador  All ages               729
# 1  1972  Newfoundland and Labrador  All ages               751
# 2  1973  Newfoundland and Labrador  All ages              1128
# 3  1974  Newfoundland and Labrador  All ages               995
# 4  1975  Newfoundland and Labrador  All ages              1013

# %%
filt_immigration_df['Year'] = filt_immigration_df['Year'].astype(int)

ontario_immigration = filt_immigration_df.loc[
    (filt_immigration_df["GEO"] == "Ontario") &
    (filt_immigration_df["Age group"] == "All ages") &
    (filt_immigration_df["Year"] >= 1976) & (filt_immigration_df["Year"] <= 2022)]

ontario_immigration.rename(columns={"Age group": "Immigrant Age Group"}, inplace=True)


ontario_immigration.head()
# Out:
# C:\Users\Rob\AppData\Local\Temp\ipykernel_10000\2988609725.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ontario_immigration.rename(columns={"Age group": "Immigrant Age Group"}, inplace=True)
#      Year      GEO Immigrant Age Group  Total Immigrants
# 265  1976  Ontario            All ages             63267
# 266  1977  Ontario            All ages             49986
# 267  1978  Ontario            All ages             40768
# 268  1979  Ontario            All ages             64536
# 269  1980  Ontario            All ages             54648

# %%
filt_unemployed_df['Year'] = filt_unemployed_df['Year'].astype(int)

ontario_unemploy = filt_unemployed_df.loc[
    (filt_unemployed_df["GEO"] == "Ontario") &
    (filt_unemployed_df["Age group"] == "15 years and over") &
    (filt_unemployed_df["Month"] == "01") &
    (filt_unemployed_df['Year'] <= 2022) & (filt_unemployed_df["Year"] >= 1976)]



ontario_unemploy.head()
# Out:
#       Year Month      GEO          Age group  Population  Labour force  \
# 47    1976    01  Ontario  15 years and over   6136300.0     3960000.0
# 875   1977    01  Ontario  15 years and over   6275000.0     4048300.0
# 1703  1978    01  Ontario  15 years and over   6407200.0     4148400.0
# 2531  1979    01  Ontario  15 years and over   6526600.0     4342200.0
# 3359  1980    01  Ontario  15 years and over   6644300.0     4442100.0
#
#       Employment  Unemployment  Participation rate  Employment rate  \
# 47     3707400.0      252700.0                64.5             60.4
# 875    3776600.0      271700.0                64.5             60.2
# 1703   3859000.0      289300.0                64.7             60.2
# 2531   4036700.0      305500.0                66.5             61.8
# 3359   4146900.0      295100.0                66.9             62.4
#
#       Unemployment rate
# 47                  6.4
# 875                 6.7
# 1703                7.0
# 2531                7.0
# 3359                6.6

# %%
ontario_merge = pd.merge(ontario_immigration, ontario_unemploy, how="left", on=["Year", "GEO"])




ontario_merge.head()
# Out:
#    Year      GEO Immigrant Age Group  Total Immigrants Month  \
# 0  1976  Ontario            All ages             63267    01
# 1  1977  Ontario            All ages             49986    01
# 2  1978  Ontario            All ages             40768    01
# 3  1979  Ontario            All ages             64536    01
# 4  1980  Ontario            All ages             54648    01
#
#            Age group  Population  Labour force  Employment  Unemployment  \
# 0  15 years and over   6136300.0     3960000.0   3707400.0      252700.0
# 1  15 years and over   6275000.0     4048300.0   3776600.0      271700.0
# 2  15 years and over   6407200.0     4148400.0   3859000.0      289300.0
# 3  15 years and over   6526600.0     4342200.0   4036700.0      305500.0
# 4  15 years and over   6644300.0     4442100.0   4146900.0      295100.0
#
#    Participation rate  Employment rate  Unemployment rate
# 0                64.5             60.4                6.4
# 1                64.5             60.2                6.7
# 2                64.7             60.2                7.0
# 3                66.5             61.8                7.0
# 4                66.9             62.4                6.6

# %%
fig, ax = plt.subplots()
ax.bar(ontario_immigration["Year"], ontario_immigration['Total Immigrants'], color='skyblue', label="Immigration")

ax2= ax.twinx()

ax2.plot(ontario_unemploy["Year"], ontario_unemploy['Unemployment rate'], color='red', label="Unemployment Rate")

ax.legend()

ax.plot()
# Out:
# []

# %%
filt_immigration_df['Year'] = filt_immigration_df['Year'].astype(int)

quebec_immigration = filt_immigration_df.loc[
    (filt_immigration_df["GEO"] == "Quebec") &
    (filt_immigration_df["Age group"] == "All ages") &
    (filt_immigration_df["Year"] >= 1970) & (filt_immigration_df["Year"] <= 2022)]

bc_immigration = filt_immigration_df.loc[
    (filt_immigration_df["GEO"] == "British Columbia") &
    (filt_immigration_df["Age group"] == "All ages") &
    (filt_immigration_df["Year"] >= 1970) & (filt_immigration_df["Year"] <= 2022)]

alberta_immigration = filt_immigration_df.loc[
    (filt_immigration_df["GEO"] == "Alberta") &
    (filt_immigration_df["Age group"] == "All ages") &
    (filt_immigration_df["Year"] >= 1970) & (filt_immigration_df["Year"] <= 2022)]

# %%
plt.plot(ontario_immigration['Year'], ontario_immigration['Total Immigrants'], label='Ontario')


plt.plot(quebec_immigration['Year'], quebec_immigration['Total Immigrants'], label='Quebec')


plt.plot(bc_immigration['Year'], bc_immigration['Total Immigrants'], label='British Columbia')

plt.plot(alberta_immigration['Year'], alberta_immigration['Total Immigrants'], label='Alberta')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Total Immigrants')
plt.title('Immigration for Ontario, Quebec, and British Columbia')
plt.grid()
plt.legend()

# Display the plot
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:blue'
ax1.set_xlabel('Year')
ax1.set_ylabel('Immigration Rate', color=color)
ax1.scatter(ontario_immigration['Year'], ontario_immigration['Total Immigrants'], color=color, label='Immigration Rate')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('Unemployment Rate', color=color)
ax2.scatter(ontario_unemploy['Year'], ontario_unemploy['Unemployment rate'], color=color, label='Unemployment Rate')
ax2.tick_params(axis='y', labelcolor=color)

fig.suptitle('Immigration vs Unemployment Rates')
fig.legend(loc="upper left")
fig.tight_layout()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(ontario_immigration['Year'], ontario_immigration['Total Immigrants'], label='Immigration Rate')
plt.scatter(ontario_unemploy['Year'], ontario_unemploy['Unemployment rate'], label='Unemployment Rate')
plt.xlabel('Year')
plt.ylabel('Rate')
plt.title('Immigration vs Unemployment Rates')
plt.legend()
plt.grid(True)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

color = 'tab:red'
ax1.set_xlabel('Year')
ax1.set_ylabel('Immigration', color=color)
ax1.plot(ontario_immigration['Year'], ontario_immigration['Total Immigrants'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  
color = 'tab:blue'
ax2.set_ylabel('Unemployment Rate', color=color)  
ax2.plot(ontario_unemploy['Year'], ontario_unemploy['Unemployment rate'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
plt.xticks(rotation=90)
plt.legend()

fig.tight_layout()  
plt.title('Immigration vs Unemployment Rates')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))
from scipy.stats import linregress

color = 'tab:blue'
ax1.set_xlabel('Unemployment Rate')
ax1.set_ylabel('Immigration Rate', color=color)
ax1.scatter(ontario_merge['Unemployment rate'], ontario_merge['Total Immigrants'], color=color, label='Immigration Rate')
ax1.tick_params(axis='y', labelcolor=color)


(slope, intercept, rvalue, pvalue, stderr) = linregress(ontario_merge['Unemployment rate'], ontario_merge['Total Immigrants'])
regress_values = ontario_merge['Unemployment rate'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.annotate(line_eq,(9, 75000), color='r')
plt.plot(ontario_merge['Unemployment rate'], regress_values, "r-")
fig.suptitle('Immigration vs Unemployment Rates')
fig.legend(loc="upper left")
fig.tight_layout()
print(f"R squared: {rvalue**2}")
plt.grid(True)
plt.show()
# Out:
# R squared: 1.3159424872773572e-05

# %% [markdown]
# # Unemployment vs. EI

# %% [markdown]
# Unemployment Vs
